# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv2.imread('./train/51_right.jpeg', cv2.IMREAD_UNCHANGED)
print(src.shape)
# Out:
# (3168, 4752, 3)

# %%
plt.imshow(img)
